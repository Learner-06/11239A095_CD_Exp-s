# %% [markdown]
# <a href="https://colab.research.google.com/github/Learner-06/11239A095_CD_Exp-s/blob/main/CD_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Reuse the shift-reduce parser from topic 8.
def shift_reduce(expr):
 stack = []
 tokens = expr.split()
 while tokens:
  stack.append(tokens.pop(0))
  print("Shift:", stack)
  while len(stack) >= 3 and stack[-2] == '*':
      stack[-3:] = ['E']
      print("Reduce:", stack)
 return stack
print(shift_reduce("principal + (principal * rate)"))
# Out:
# Shift: ['principal']
# Shift: ['principal', '+']
# Shift: ['principal', '+', '(principal']
# Shift: ['principal', '+', '(principal', '*']
# Shift: ['principal', '+', '(principal', '*', 'rate)']
# Reduce: ['principal', '+', 'E']
# ['principal', '+', 'E']
