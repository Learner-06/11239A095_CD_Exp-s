# %% [markdown]
# <a href="https://colab.research.google.com/github/Learner-06/11239A095_CD_Exp-s/blob/main/CD_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def wc(filename):
 with open(filename, 'r', encoding='utf-8') as f:
  text = f.read()
 lines = text.count('\n') + 1 if text else 0
 words = len(text.split())
 chars = len(text)
 return lines, words, chars
# Example usage:
# print(wc("feedback.txt"))
