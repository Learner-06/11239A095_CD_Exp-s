# %% [markdown]
# <a href="https://colab.research.google.com/github/Learner-06/11239A095_CD_Exp-s/blob/main/CD_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_balanced(expr):
 stack = []
 for ch in expr:
  if ch == '(':
    stack.append(ch)
  elif ch == ')':
    if not stack:
      return False
    stack.pop()
 return len(stack) == 0
expr1 = "(deposit + withdraw - transfer))"
print(is_balanced(expr1)) # False
expr2 = "((math + science) + (english + social))"
print(is_balanced(expr2)) # True
# Out:
# False
# True
